# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
from os.path import join as opj
from scipy.io import loadmat
import pickle

# %%
data_dir = "/home/javier/Documentos/amaia-abide/data/"
plot_dir = "/home/javier/Documentos/amaia-abide/plots"

# %%
demo_data = pd.read_csv(opj(data_dir, "abide_I_II_demo_clean.csv"))
cons_res=loadmat('../data/results_clustering_both.mat', 
                            struct_as_record=False, 
                            squeeze_me=True)['res_cluster_pearson']

# %%
f = open(opj(data_dir, "subjects_subgroups.pkl"), "rb")
subjects_subgroups = pickle.load(f, encoding='utf-8')
f.close()

asd_subjects = subjects_subgroups['asd_subjs']
tc_subjects = subjects_subgroups['tc_subjs']

subjects = np.concatenate((tc_subjects, asd_subjects))

# %%
len(subjects)
# Out:
# 1890

# %%
len(asd_subjects)
# Out:
# 880

# %%
S = cons_res.S.flatten()
#clus_subj = cons_res['clus_subj'][0]
cons_mat = cons_res.C

# %%
clus_idxs = [np.where(S==ii)[0] for ii in np.unique(S)]
clus_subj = [asd_subjects[idxs] for idxs in clus_idxs]

# %%
n_1, n_2, n_3 = len(clus_idxs[0]), len(clus_idxs[1]), len(clus_idxs[2])

# %%
current_palette=sns.color_palette('colorblind')
sns.palplot(sns.color_palette('colorblind'))

# %%
fig, ax = plt.subplots(figsize=(10, 10))
im= ax.imshow(cons_mat[np.concatenate(clus_idxs), :][:,np.concatenate(clus_idxs)], 
              cmap = plt.cm.jet, vmin=0.1, vmax=0.5)
ax.set_title("CONSENSUS MATRIX", {"fontsize":40, "fontweight":"bold"})
ax.set_xlabel("ASD subjects", {"fontsize": 30, "fontweight":"bold"})
ax.set_ylabel("ASD subjects", {"fontsize": 30, "fontweight":"bold"})
cbar=plt.colorbar(im,fraction=0.046, pad=0.04)

x0, xf = 0, n_1
y0, yf = 0, n_1

plt.vlines(x=x0 + 1, ymin =y0, ymax = yf , color=current_palette[4], linewidth=3)
plt.vlines(x=xf, ymin =y0, ymax = yf - 1, color=current_palette[4],  linewidth=3)

plt.hlines(y=y0 + 1, xmin =x0, xmax = xf-1, color=current_palette[4],  linewidth=3)
plt.hlines(y=yf, xmin =x0, xmax = xf-1, color=current_palette[4],  linewidth=3, label="Subtype 1")


x0 = xf
xf += n_2
y0 = yf
yf += n_2

plt.vlines(x=x0, ymin =y0, ymax = yf , color=sns.color_palette()[1],  linewidth=3)
plt.vlines(x=xf, ymin =y0, ymax = yf - 1, color=sns.color_palette()[1], linewidth=3)
plt.hlines(y=y0, xmin =x0, xmax = xf-1, color=sns.color_palette()[1], linewidth=3)
plt.hlines(y=yf, xmin =x0, xmax = xf-1, color=sns.color_palette()[1], linewidth=3,  label="Subtype 2")

x0 = xf
xf += n_3
y0 = yf
yf += n_3

plt.vlines(x=x0, ymin =y0, ymax = yf , color=sns.color_palette()[2],  linewidth=3)
plt.vlines(x=xf, ymin =y0, ymax = yf - 1, color=sns.color_palette()[2],  linewidth=3)
plt.hlines(y=y0, xmin =x0, xmax = xf-1, color=sns.color_palette()[2],  linewidth=3)
plt.hlines(y=yf, xmin =x0, xmax = xf-1, color=sns.color_palette()[2],  linewidth=3,  label="Subtype 3")

x0 = xf
xf += len(clus_idxs[3])
y0 = yf
yf += len(clus_idxs[3])
plt.legend(ncol=2, prop={'size':15, 'weight':'bold'})
ax.tick_params(labelsize=15)
cbar.ax.tick_params(labelsize=15) 
plt.savefig(opj(plot_dir, "consensus_mat.png"), dpi=600)
plt.savefig(opj(plot_dir, "consensus_mat.svg"), dpi=600)

# %% [markdown]
# ## Explore the behaviour

# %%
common_pheno_abide = pd.read_csv(opj(data_dir, "common_pheno_abide.csv"))

# %%
common_pheno_abide = common_pheno_abide.replace(to_replace = -9999.0, value=np.nan)

# %%
common_pheno_abide.HANDEDNESS_CATEGORY = common_pheno_abide.HANDEDNESS_CATEGORY.replace(to_replace = ["1.0", "2.0", "3.0"], 
                                                                                        value = ["R", "L", "Ambi"])

# %%
# Out:
#       participant_id
# 1782           28675
# 1786           28681
# 1787           28683
# 1783           28684
# 1784           28685
# ...              ...
# 1256           51583
# 1257           51584
# 1258           51585
# 1097           51606
# 1098           51607
#
# [1890 rows x 1 columns]

# %%
pd.DataFrame({"participant_id":pd.merge(pd.DataFrame({'SUB_ID':subjects}), demo_clean , on = 'SUB_ID').SUB_ID}).sort_values(by="participant_id").to_csv("../data/study_subjects_id.txt", 
                                                                                                                       index=False)

# %%
print(np.round(pd.merge(pd.DataFrame({'SUB_ID':asd_subjects}), common_pheno_abide , on = 'SUB_ID').ADOS_TOTAL.mean(), 2))
print(np.round(pd.merge(pd.DataFrame({'SUB_ID':asd_subjects}), common_pheno_abide , on = 'SUB_ID').ADOS_TOTAL.std(), 2))
# Out:
# 11.52
# 3.85

# %%
# Rewrite site
demo_clean = pd.read_csv(opj(data_dir, "abide_I_II_demo_clean.csv"))
common_pheno_abide.SITE_ID = pd.merge(common_pheno_abide, demo_clean, on="SUB_ID")['SITE_ID_y']

# %%
# Beware, first subjects on the merge to preserve this order
demo_w_clusters = pd.merge(pd.DataFrame({'SUB_ID':subjects}), common_pheno_abide , on = 'SUB_ID')

# %%
demo_w_clusters.head()
# Out:
#    SUB_ID  SITE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  SEX HANDEDNESS_CATEGORY  \
# 0   51475  CALTECH         2        0.0         44.2    1                   R
# 1   51476  CALTECH         2        0.0         39.3    1                   R
# 2   51477  CALTECH         2        0.0         42.5    1                   R
# 3   51478  CALTECH         2        0.0         19.7    1                   R
# 4   51479  CALTECH         2        0.0         20.0    2                   R
#
#    HANDEDNESS_SCORES    FIQ    VIQ  ...  VINELAND_PLAY_V_SCALED  \
# 0                NaN  104.0  113.0  ...                     NaN
# 1                NaN  123.0  127.0  ...                     NaN
# 2                NaN   97.0   85.0  ...                     NaN
# 3                NaN  116.0  117.0  ...                     NaN
# 4                NaN  111.0  110.0  ...                     NaN
#
#   VINELAND_COPING_V_SCALED VINELAND_SOCIAL_STANDARD VINELAND_SUM_SCORES  \
# ...

# %% [markdown]
# Add cluster ID column

# %%
demo_w_clusters['clus_id'] = pd.NA

demo_w_clusters.loc[demo_w_clusters.SUB_ID.isin(tc_subjects), 'clus_id'] = 0

for ii, sub_clus in enumerate(clus_subj):
    demo_w_clusters.loc[demo_w_clusters.SUB_ID.isin(sub_clus), 'clus_id'] = ii+1

# %%
demo_w_clusters.clus_id.value_counts()
# Out:
# 0    1010
# 3     464
# 2     278
# 1     121
# 5      10
# 4       4
# 7       2
# 6       1
# Name: clus_id, dtype: int64

# %%
from scipy.stats import chi2_contingency, fisher_exact
fisher_exact(pd.crosstab(demo_w_clusters.SEX, 
                         demo_w_clusters.DX_GROUP).values)
# Out:
# (1.8991848991848992, 1.288911987574412e-07)

# %%
# Save this to disk for further use
#demo_w_clusters.to_excel(opj('../data','pheno_w_clusters.xlsx'), index=False)
demo_w_clusters.to_excel(opj('../data','pheno_w_clusters.xlsx'), index=False)

# %%
from scipy.stats import chi2_contingency, kruskal, f_oneway, shapiro

# %%
float_columns = demo_w_clusters.select_dtypes(float).columns

p_columns=[]
for column in float_columns:
    f, p = kruskal(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id,column].dropna() for 
                     clus_id in [1,2,3]])
    print(" kruskal-wallis of %s across modules = %.5f" %(column, p))
    
    if p<0.05:
        p_columns.append(column)
# Out:
#  kruskal-wallis of DSM_IV_TR across modules = 0.07729
#  kruskal-wallis of AGE_AT_SCAN across modules = 0.00004
#  kruskal-wallis of HANDEDNESS_SCORES across modules = 0.15039
#  kruskal-wallis of FIQ across modules = 0.23033
#  kruskal-wallis of VIQ across modules = 0.06234
#  kruskal-wallis of PIQ across modules = 0.38797
#  kruskal-wallis of ADI_R_SOCIAL_TOTAL_A across modules = 0.19159
#  kruskal-wallis of ADI_R_VERBAL_TOTAL_BV across modules = 0.22822
#  kruskal-wallis of ADI_RRB_TOTAL_C across modules = 0.23293
#  kruskal-wallis of ADI_R_ONSET_TOTAL_D across modules = 0.93035
#  kruskal-wallis of ADI_R_RSRCH_RELIABLE across modules = 0.49376
#  kruskal-wallis of ADOS_MODULE across modules = 0.00146
#  kruskal-wallis of ADOS_TOTAL across modules = 0.53068
#  kruskal-wallis of ADOS_COMM across modules = 0.50229
#  kruskal-wallis of ADOS_SOCIAL across modules = 0.20287
#  kruskal-wallis of ADOS_STEREO_BEHAV across modules = 0.11590
# ...

# %%
colors = [current_palette[4], current_palette[1], current_palette[2]]

# %%
demo_w_clusters.columns
iq_scores = ['FIQ', 'VIQ', 'PIQ']
adi_scores = ['ADI_R_SOCIAL_TOTAL_A', 'ADI_R_VERBAL_TOTAL_BV', 'ADI_RRB_TOTAL_C',
              'ADI_R_ONSET_TOTAL_D']
src_scores = ['SRS_RAW_TOTAL', 'SRS_AWARENESS', 'SRS_COGNITION', 'SRS_COMMUNICATION',
              'SRS_MOTIVATION', 'SRS_MANNERISMS']

ados_scores = ['ADOS_TOTAL', 'ADOS_COMM', 'ADOS_SOCIAL', 'ADOS_STEREO_BEHAV',
               'ADOS_GOTHAM_SOCAFFECT', 'ADOS_GOTHAM_RRB',
               'ADOS_GOTHAM_TOTAL', 'ADOS_GOTHAM_SEVERITY']

# %%
kruskal(demo_w_clusters[demo_w_clusters.clus_id==0]['SRS_RAW_TOTAL'].dropna().values,
         demo_w_clusters[demo_w_clusters.clus_id==2]['SRS_RAW_TOTAL'].dropna().values)
# Out:
# KruskalResult(statistic=351.2565997522966, pvalue=2.2568286638276164e-78)

# %%
demo_w_clusters.loc[cond,:].describe().T
# Out:
#                                  count          mean           std  \
# SUB_ID                           863.0  41053.085747  10706.059152
# DX_GROUP                         863.0      1.000000      0.000000
# DSM_IV_TR                        667.0      1.517241      0.802166
# AGE_AT_SCAN                      863.0     16.059254      9.040064
# SEX                              863.0      1.133256      0.340048
# HANDEDNESS_SCORES                386.0     58.560271     52.246755
# FIQ                              804.0    106.322761     16.565974
# VIQ                              699.0    106.077253     17.934609
# PIQ                              713.0    105.837307     16.662594
# ADI_R_SOCIAL_TOTAL_A             585.0     19.254701      5.502965
# ADI_R_VERBAL_TOTAL_BV            585.0     15.382906      4.604983
# ADI_RRB_TOTAL_C                  585.0      5.810256      2.482796
# ADI_R_ONSET_TOTAL_D              517.0      3.104449      1.316532
# ...

# %%
beh_scores = ['FIQ', 'VIQ', 'PIQ', 
              'ADI_R_SOCIAL_TOTAL_A', 'ADI_R_VERBAL_TOTAL_BV', 'ADI_RRB_TOTAL_C',
              'ADI_R_ONSET_TOTAL_D', 'ADI_R_RSRCH_RELIABLE',
              'ADOS_TOTAL', 'ADOS_COMM', 'ADOS_SOCIAL', 'ADOS_STEREO_BEHAV',
              'ADOS_RSRCH_RELIABLE', 'ADOS_GOTHAM_SOCAFFECT', 'ADOS_GOTHAM_RRB',
              'ADOS_GOTHAM_TOTAL', 'ADOS_GOTHAM_SEVERITY']


cond = (demo_w_clusters.clus_id == 1) | (demo_w_clusters.clus_id == 2) | (demo_w_clusters.clus_id == 3)
beh_table = []
for var in beh_scores:
    
    row = [np.round(demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].mean(), 2) for 
             clus_id in [1,2,3]]
    
    f, p = f_oneway(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].dropna() for 
                         clus_id in [1,2,3]])
    
    row = row + [np.round(p, 2)]
    beh_table.append(row)
    print(var, "=", p)
beh_table = pd.DataFrame(beh_table)
beh_table.index = beh_scores
beh_table.columns = ['cluster 1', 'cluster 2', 'cluster 3', 'p-value']
beh_table.head()
# Out:
# FIQ = 0.13648118123452457
# VIQ = 0.11424774706062289
# PIQ = 0.6048855023168267
# ADI_R_SOCIAL_TOTAL_A = 0.2202791782901848
# ADI_R_VERBAL_TOTAL_BV = 0.11708427466286268
# ADI_RRB_TOTAL_C = 0.6540333526291837
# ADI_R_ONSET_TOTAL_D = 0.5896864699314831
# ADI_R_RSRCH_RELIABLE = 0.5551779438313649
# ADOS_TOTAL = 0.2517459316220886
# ADOS_COMM = 0.3568711830180537
# ADOS_SOCIAL = 0.0694108549717804
# ADOS_STEREO_BEHAV = 0.11642016156458936
# ADOS_RSRCH_RELIABLE = 0.5457870750529443
# ADOS_GOTHAM_SOCAFFECT = 0.33419294925550946
# ADOS_GOTHAM_RRB = 0.3300398264145052
# ADOS_GOTHAM_TOTAL = 0.22953378129614363
# ADOS_GOTHAM_SEVERITY = 0.2572660642256111
#                        cluster 1  cluster 2  cluster 3  p-value
# FIQ                       103.74     107.34     106.42     0.14
# VIQ                       102.71     106.40     106.79     0.11
# PIQ                       104.42     106.39     105.82     0.60
# ADI_R_SOCIAL_TOTAL_A       18.34      19.26      19.50     0.22
# ...

# %%
beh_scores = ['FIQ', 'VIQ', 'PIQ', 
              'ADI_R_SOCIAL_TOTAL_A', 'ADI_R_VERBAL_TOTAL_BV', 'ADI_RRB_TOTAL_C',
              'ADI_R_ONSET_TOTAL_D', 'ADI_R_RSRCH_RELIABLE',
              'ADOS_TOTAL', 'ADOS_COMM', 'ADOS_SOCIAL', 'ADOS_STEREO_BEHAV',
              'ADOS_RSRCH_RELIABLE', 'ADOS_GOTHAM_SOCAFFECT', 'ADOS_GOTHAM_RRB',
              'ADOS_GOTHAM_TOTAL', 'ADOS_GOTHAM_SEVERITY']


cond = (demo_w_clusters.clus_id == 1) | (demo_w_clusters.clus_id == 2) | (demo_w_clusters.clus_id == 3)
beh_table = []
for var in beh_scores:
    
    row = [np.round(demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].mean(), 2) for 
             clus_id in [1,2,3]]
    
    f, p = kruskal(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].dropna() for 
                         clus_id in [1,2,3]])
    
    row = row + [np.round(p, 2)]
    beh_table.append(row)
    print(var, "=", p)
beh_table = pd.DataFrame(beh_table)
beh_table.index = beh_scores
beh_table.columns = ['cluster 1', 'cluster 2', 'cluster 3', 'p-value']
#beh_table.head()
# Out:
# FIQ = 0.23032954771673142
# VIQ = 0.062343606159740744
# PIQ = 0.3879710927354524
# ADI_R_SOCIAL_TOTAL_A = 0.19159248538331042
# ADI_R_VERBAL_TOTAL_BV = 0.2282228857417346
# ADI_RRB_TOTAL_C = 0.23293348992425073
# ADI_R_ONSET_TOTAL_D = 0.9303534959858084
# ADI_R_RSRCH_RELIABLE = 0.4937642324832814
# ADOS_TOTAL = 0.530684518598296
# ADOS_COMM = 0.5022899963608141
# ADOS_SOCIAL = 0.20287237649924766
# ADOS_STEREO_BEHAV = 0.11590066221974464
# ADOS_RSRCH_RELIABLE = 0.5305118339032229
# ADOS_GOTHAM_SOCAFFECT = 0.48098792251786326
# ADOS_GOTHAM_RRB = 0.27263621438509206
# ADOS_GOTHAM_TOTAL = 0.27461926444216067
# ADOS_GOTHAM_SEVERITY = 0.2734356384354889

# %%
from statsmodels.stats.multitest import multipletests
multipletests(beh_table.iloc[:,3].values, method="fdr_bh")
# Out:
# (array([False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False]),
#  array([0.459   , 0.459   , 0.563125, 0.459   , 0.459   , 0.459   ,
#         0.93    , 0.563125, 0.563125, 0.563125, 0.459   , 0.459   ,
#         0.563125, 0.563125, 0.459   , 0.459   , 0.459   ]),
#  0.0030127052790058784,
#  0.0029411764705882353)

# %%
beh_scores = ['FIQ', 'VIQ', 'PIQ', 
              'ADI_R_SOCIAL_TOTAL_A', 'ADI_R_VERBAL_TOTAL_BV', 'ADI_RRB_TOTAL_C',
              'ADI_R_ONSET_TOTAL_D', 'ADI_R_RSRCH_RELIABLE',
              'ADOS_TOTAL', 'ADOS_COMM', 'ADOS_SOCIAL', 'ADOS_STEREO_BEHAV',
              'ADOS_RSRCH_RELIABLE', 'ADOS_GOTHAM_SOCAFFECT', 'ADOS_GOTHAM_RRB',
              'ADOS_GOTHAM_TOTAL', 'ADOS_GOTHAM_SEVERITY']


cond = (demo_w_clusters.clus_id == 1) | (demo_w_clusters.clus_id == 2) | (demo_w_clusters.clus_id == 3)
beh_table = []
for var in beh_scores:
    
    row = [np.round(demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].mean(), 2) for 
             clus_id in [1,2,3]]
    
    f, p = f_oneway(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].dropna() for 
                         clus_id in [1,2,3]])
    
    row = row + [np.round(p, 2)]
    beh_table.append(row)
    print(var, "=", p)
beh_table = pd.DataFrame(beh_table)
beh_table.index = beh_scores
beh_table.columns = ['cluster 1', 'cluster 2', 'cluster 3', 'p-value']
beh_table.head()
# Out:
# FIQ = 0.2690310986517191
# VIQ = 0.11594125932490283
# PIQ = 0.6178942856255853
# ADI_R_SOCIAL_TOTAL_A = 0.10455101651930326
# ADI_R_VERBAL_TOTAL_BV = 0.2271376582534797
# ADI_RRB_TOTAL_C = 0.39695666192416434
# ADI_R_ONSET_TOTAL_D = 0.8991228890230961
# ADI_R_RSRCH_RELIABLE = 0.49452225471368993
# ADOS_TOTAL = 0.5214093237235271
# ADOS_COMM = 0.47595498936842007
# ADOS_SOCIAL = 0.21136863822457447
# ADOS_STEREO_BEHAV = 0.2245187196575879
# ADOS_RSRCH_RELIABLE = 0.5311894028752221
# ADOS_GOTHAM_SOCAFFECT = 0.5219484582468507
# ADOS_GOTHAM_RRB = 0.18875076707802418
# ADOS_GOTHAM_TOTAL = 0.3867453921979065
# ADOS_GOTHAM_SEVERITY = 0.35769102674125924
#                        cluster 1  cluster 2  cluster 3  p-value
# FIQ                       104.10     106.98     106.54     0.27
# VIQ                       102.68     106.26     106.87     0.12
# PIQ                       104.37     106.29     105.94     0.62
# ADI_R_SOCIAL_TOTAL_A       18.08      19.46      19.45     0.10
# ...

# %%
# New Javi... remove one of those!
beh_scores = ['FIQ', 'VIQ', 'PIQ', 
              'ADI_R_SOCIAL_TOTAL_A', 'ADI_R_VERBAL_TOTAL_BV', 'ADI_RRB_TOTAL_C',
              'ADI_R_ONSET_TOTAL_D', 'ADI_R_RSRCH_RELIABLE',
              'ADOS_TOTAL', 'ADOS_COMM', 'ADOS_SOCIAL', 'ADOS_STEREO_BEHAV',
              'ADOS_RSRCH_RELIABLE', 'ADOS_GOTHAM_SOCAFFECT', 'ADOS_GOTHAM_RRB',
              'ADOS_GOTHAM_TOTAL', 'ADOS_GOTHAM_SEVERITY']


cond = (demo_w_clusters.clus_id == 1) | (demo_w_clusters.clus_id == 2) | (demo_w_clusters.clus_id == 3)
beh_table = []
for var in beh_scores:
    
    row = [np.round(demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].mean(), 2) for 
             clus_id in [1,2,3]]
    
    f, p = f_oneway(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].dropna() for 
                         clus_id in [1,2,3]])
    
    row = row + [np.round(p, 2)]
    beh_table.append(row)
    print(var, "=", p)
beh_table = pd.DataFrame(beh_table)
beh_table.index = beh_scores
beh_table.columns = ['cluster 1', 'cluster 2', 'cluster 3', 'p-value']
beh_table.head()
# Out:
# FIQ = 0.13648118123452457
# VIQ = 0.11424774706062289
# PIQ = 0.6048855023168267
# ADI_R_SOCIAL_TOTAL_A = 0.2202791782901848
# ADI_R_VERBAL_TOTAL_BV = 0.11708427466286268
# ADI_RRB_TOTAL_C = 0.6540333526291837
# ADI_R_ONSET_TOTAL_D = 0.5896864699314831
# ADI_R_RSRCH_RELIABLE = 0.5551779438313649
# ADOS_TOTAL = 0.2517459316220886
# ADOS_COMM = 0.3568711830180537
# ADOS_SOCIAL = 0.0694108549717804
# ADOS_STEREO_BEHAV = 0.11642016156458936
# ADOS_RSRCH_RELIABLE = 0.5457870750529443
# ADOS_GOTHAM_SOCAFFECT = 0.33419294925550946
# ADOS_GOTHAM_RRB = 0.3300398264145052
# ADOS_GOTHAM_TOTAL = 0.22953378129614363
# ADOS_GOTHAM_SEVERITY = 0.2572660642256111
#                        cluster 1  cluster 2  cluster 3  p-value
# FIQ                       103.74     107.34     106.42     0.14
# VIQ                       102.71     106.40     106.79     0.11
# PIQ                       104.42     106.39     105.82     0.60
# ADI_R_SOCIAL_TOTAL_A       18.34      19.26      19.50     0.22
# ...

# %%
iq_vars = ['FIQ', 'VIQ', 'PIQ']

fig, ax = plt.subplots(figsize=(10, 7))
sns.barplot(hue='clus_id', y='value',x='variable', 
            data = pd.melt(demo_w_clusters[demo_w_clusters.clus_id<4], 
                           id_vars=['clus_id'], 
                           value_vars=iq_vars), 
            capsize=0.05, 
            ax=ax, 
            errcolor='.2', 
            palette=[current_palette[0], current_palette[4], 
                     current_palette[1], current_palette[2]],
            saturation=1,
            n_boot=1000,
            seed=0
           )

plt.ylim([90, 120])
ax.tick_params(labelsize=20)
ax.set_xlabel("")
ax.set_ylabel("Intelligence Quotient Score", size=25)
ax.legend(['TDC', 'Subtype 1', 'Subtype 2', 'Subtype 3'], 
          fontsize=15, prop={'size':15,'weight':'bold'}, handlelength=1)
sns.despine()
ax.get_legend().legendHandles[0].set_color(current_palette[0])
ax.get_legend().legendHandles[1].set_color(current_palette[4])
ax.get_legend().legendHandles[2].set_color(current_palette[1])
ax.get_legend().legendHandles[3].set_color(current_palette[2])
plt.savefig('../plots/fig_s_iq.svg', dpi=600)
plt.savefig('../plots/fig_s_iq.png', dpi=600)

# %%
iq_vars = ['FIQ', 'VIQ', 'PIQ']

fig, ax = plt.subplots(figsize=(10, 7))
sns.barplot(hue='clus_id', y='value',x='variable', 
            data = pd.melt(demo_w_clusters[demo_w_clusters.clus_id<4], 
                           id_vars=['clus_id'], 
                           value_vars=iq_vars), 
            capsize=0.05, 
            ax=ax, 
            errcolor='.2', 
            palette=[current_palette[0], current_palette[4], 
                     current_palette[1], current_palette[2]],
            saturation=1,
            n_boot=1000,
            seed=0
           )

plt.ylim([90, 120])
ax.tick_params(labelsize=20)
ax.set_xlabel("")
ax.set_ylabel("")
ax.legend(['TDC', 'Cluster 1', 'Cluster 2', 'Cluster 3'], 
          fontsize=15, prop={'size':15,'weight':'bold'}, handlelength=1)
sns.despine()
ax.get_legend().legendHandles[0].set_color(current_palette[0])
ax.get_legend().legendHandles[1].set_color(current_palette[4])
ax.get_legend().legendHandles[2].set_color(current_palette[1])
ax.get_legend().legendHandles[3].set_color(current_palette[2])
plt.savefig('../plots/fig_s_iq.svg', dpi=600)
plt.savefig('../plots/fig_s_iq.png', dpi=600)

# %%
demo_w_clusters[demo_w_clusters.clus_id<4].loc[:, ['clus_id'] + adi_vars].dropna()
# Out:
#      clus_id  ADI_R_SOCIAL_TOTAL_A  ADI_R_VERBAL_TOTAL_BV  ADI_RRB_TOTAL_C  \
# 1011       2                  23.0                   17.0              5.0
# 1012       3                  13.0                   18.0              7.0
# 1013       2                  12.0                   12.0              2.0
# 1014       3                  21.0                   11.0              6.0
# 1016       2                  25.0                   18.0              3.0
# ...      ...                   ...                    ...              ...
# 1838       3                  18.0                   16.0              4.0
# 1839       2                  18.0                    8.0              3.0
# 1840       3                  14.0                    9.0              3.0
# 1841       3                  16.0                   13.0              3.0
# 1842       3                  15.0                   12.0              5.0
#
#       ADI_R_ONSET_TOTAL_D  ADI_R_RSRCH_RELIABLE
# ...

# %%
pd.melt(demo_w_clusters[demo_w_clusters.clus_id<4].loc[:, ['clus_id'] + adi_vars].dropna(), 
                           id_vars=['clus_id'], 
                           value_vars=adi_vars)
# Out:
#      clus_id              variable  value
# 0          2  ADI_R_SOCIAL_TOTAL_A   23.0
# 1          3  ADI_R_SOCIAL_TOTAL_A   13.0
# 2          2  ADI_R_SOCIAL_TOTAL_A   12.0
# 3          3  ADI_R_SOCIAL_TOTAL_A   21.0
# 4          2  ADI_R_SOCIAL_TOTAL_A   25.0
# ...      ...                   ...    ...
# 2570       3  ADI_R_RSRCH_RELIABLE    1.0
# 2571       2  ADI_R_RSRCH_RELIABLE    1.0
# 2572       3  ADI_R_RSRCH_RELIABLE    1.0
# 2573       3  ADI_R_RSRCH_RELIABLE    1.0
# 2574       3  ADI_R_RSRCH_RELIABLE    1.0
#
# [2575 rows x 3 columns]

# %%
print(beh_table.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  cluster 1 &  cluster 2 &  cluster 3 &  p-value \\
# \midrule
# FIQ                   &     104.10 &     106.98 &     106.54 &     0.27 \\
# VIQ                   &     102.68 &     106.26 &     106.87 &     0.12 \\
# PIQ                   &     104.37 &     106.29 &     105.94 &     0.62 \\
# ADI\_R\_SOCIAL\_TOTAL\_A  &      18.08 &      19.46 &      19.45 &     0.10 \\
# ADI\_R\_VERBAL\_TOTAL\_BV &      16.18 &      15.22 &      15.27 &     0.23 \\
# ADI\_RRB\_TOTAL\_C       &       6.13 &       5.82 &       5.72 &     0.40 \\
# ADI\_R\_ONSET\_TOTAL\_D   &       3.15 &       3.12 &       3.08 &     0.90 \\
# ADI\_R\_RSRCH\_RELIABLE  &       0.92 &       0.90 &       0.88 &     0.49 \\
# ADOS\_TOTAL            &      12.00 &      11.35 &      11.52 &     0.52 \\
# ADOS\_COMM             &       3.65 &       3.55 &       3.73 &     0.48 \\
# ADOS\_SOCIAL           &       8.35 &       7.70 &       7.71 &     0.21 \\
# ...

# %%
from scipy.stats import f_oneway

# %%
#compute eta
x = demo_w_clusters.loc[(demo_w_clusters.clus_id>0) & (demo_w_clusters.clus_id<4),'clus_id']
y = demo_w_clusters.loc[(demo_w_clusters.clus_id>0) & (demo_w_clusters.clus_id<4),'AGE_AT_SCAN']

# %%
linReg.intercept_
# Out:
# 14.95569705695112

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
linReg = LinearRegression()
linReg.fit(x[:,np.newaxis], y)


#mean_squared_error(y, linReg.predict(x[:,np.newaxis])) 
r2_score(y, linReg.predict(x[:,np.newaxis]))
# Out:
# 0.0026989911553747525

# %%
f, p= f_oneway(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, 'AGE_AT_SCAN'].dropna() for 
                     clus_id in [1,2,3]])

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

foo = ols('AGE_AT_SCAN ~ C(clus_id)',
          data=demo_w_clusters.loc[(demo_w_clusters.clus_id>0) & (demo_w_clusters.clus_id<4),:]).fit()

# %%
aov[:-1]['df']
# Out:
# C(clus_id)    2.0
# Name: df, dtype: float64

# %%
aov
# Out:
#                   sum_sq     df         F   PR(>F)
# C(clus_id)    178.668261    2.0  1.093373  0.33555
# Residual    70266.343516  860.0       NaN      NaN

# %%
aov = sm.stats.anova_lm(foo, typ=2)
aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']

aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])

aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
aov
#(aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
#foo.summary()
# Out:
#                   sum_sq     df         F   PR(>F)    mean_sq    eta_sq  \
# C(clus_id)    178.668261    2.0  1.093373  0.33555  89.334131  0.002536
# Residual    70266.343516  860.0       NaN      NaN  81.705051       NaN
#
#             omega_sq
# C(clus_id)  0.000216
# Residual         NaN

# %%
from scipy.stats import chi2_contingency
chi2_contingency(pd.crosstab(demo_w_clusters.loc[(demo_w_clusters.clus_id>0) & (demo_w_clusters.clus_id<4),'SEX'],
                             demo_w_clusters.loc[(demo_w_clusters.clus_id>0) & (demo_w_clusters.clus_id<4),'clus_id']))
# Out:
# (1.5851620728925508,
#  0.45267491572512075,
#  2,
#  array([[104.8760139 , 240.95480881, 402.16917729],
#         [ 16.1239861 ,  37.04519119,  61.83082271]]))

# %%
vars_panel_c = ['ADOS_TOTAL', 'VIQ']#['ADOS_TOTAL', 'FIQ']

for var in vars_panel_c:
    fig, ax = plt.subplots(figsize=(10, 8))
    cond = (demo_w_clusters.clus_id == 1) | (demo_w_clusters.clus_id == 2) | (demo_w_clusters.clus_id == 3)
    
    h, p = kruskal(*[demo_w_clusters.loc[demo_w_clusters.clus_id==clus_id, var].dropna() for 
                     clus_id in [1,2,3]])

    sns.violinplot(x = 'clus_id', y= var, data=demo_w_clusters.loc[cond, :], 
                   inner=None,ax=ax, palette=colors, linewidth=0)
    plt.setp(ax.collections, alpha=.5)
    sns.boxplot(x = 'clus_id', y= var, data=demo_w_clusters.loc[cond, :], linewidth=2, 
                color='white', width=0.2, ax=ax, 
                notch=True, 
                bootstrap=1000, 
                boxprops=dict(linewidth=1, color='black'), 
                whiskerprops = dict(linewidth=2, color='black'),
                medianprops = dict(linewidth=2, color='black'),
                showcaps = False, 
                showfliers =False)
    ax.set_xticklabels(['cluster 1', 'cluster 2', 'cluster 3'], size=20)
    ax.tick_params(labelsize=20)
    ax.set_xlabel("")
    ax.set_ylabel(var, size=25, weight='bold')
    ax.set_title("Kruskal-Wallis p=%.3f" %( p), size=20)
    sns.despine(offset=10, trim=True)
    plt.savefig("../plots/plot_%s.png" % var, dpi=600)
    plt.savefig("../plots/plot_%s.svg" % var, dpi=600)
    #plt.savefig("../plots/panel_c_%s.png" % var )
    #plt.savefig("../plots/panel_c_%s.svg" % var )

# %%
float_columns = clus_abide_df.select_dtypes(float).columns

p_columns=[]
for column in float_columns:
    f, p = kruskal(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,column].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])
    print(" kruskal-wallis of %s across modules = %.5f" %(column, p))
    
    if p<0.05:
        p_columns.append(column)
# Out:
#  kruskal-wallis of DSM_IV_TR across modules = 0.07729
#  kruskal-wallis of AGE_AT_SCAN across modules = 0.00004
#  kruskal-wallis of HANDEDNESS_SCORES across modules = 0.15039
#  kruskal-wallis of FIQ across modules = 0.23033
#  kruskal-wallis of VIQ across modules = 0.06234
#  kruskal-wallis of PIQ across modules = 0.38797
#  kruskal-wallis of ADI_R_SOCIAL_TOTAL_A across modules = 0.19159
#  kruskal-wallis of ADI_R_VERBAL_TOTAL_BV across modules = 0.22822
#  kruskal-wallis of ADI_RRB_TOTAL_C across modules = 0.23293
#  kruskal-wallis of ADI_R_ONSET_TOTAL_D across modules = 0.93035
#  kruskal-wallis of ADI_R_RSRCH_RELIABLE across modules = 0.49376
#  kruskal-wallis of ADOS_MODULE across modules = 0.00146
#  kruskal-wallis of ADOS_TOTAL across modules = 0.53068
#  kruskal-wallis of ADOS_COMM across modules = 0.50229
#  kruskal-wallis of ADOS_SOCIAL across modules = 0.20287
#  kruskal-wallis of ADOS_STEREO_BEHAV across modules = 0.11590
# ...

# %%
float_columns = clus_abide_df.select_dtypes(float).columns

p_columns=[]
for column in float_columns:
    f, p = f_oneway(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,column].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])
    print(" kruskal-wallis of %s across modules = %.5f" %(column, p))
    
    if p<0.05:
        p_columns.append(column)
# Out:
#  kruskal-wallis of DSM_IV_TR across modules = 0.02388
#  kruskal-wallis of AGE_AT_SCAN across modules = 0.33555
#  kruskal-wallis of HANDEDNESS_SCORES across modules = 0.46627
#  kruskal-wallis of FIQ across modules = 0.26903
#  kruskal-wallis of VIQ across modules = 0.11594
#  kruskal-wallis of PIQ across modules = 0.61789
#  kruskal-wallis of ADI_R_SOCIAL_TOTAL_A across modules = 0.10455
#  kruskal-wallis of ADI_R_VERBAL_TOTAL_BV across modules = 0.22714
#  kruskal-wallis of ADI_RRB_TOTAL_C across modules = 0.39696
#  kruskal-wallis of ADI_R_ONSET_TOTAL_D across modules = 0.89912
#  kruskal-wallis of ADI_R_RSRCH_RELIABLE across modules = 0.49452
#  kruskal-wallis of ADOS_MODULE across modules = 0.00200
#  kruskal-wallis of ADOS_TOTAL across modules = 0.52141
#  kruskal-wallis of ADOS_COMM across modules = 0.47595
#  kruskal-wallis of ADOS_SOCIAL across modules = 0.21137
#  kruskal-wallis of ADOS_STEREO_BEHAV across modules = 0.22452
# ...

# %%
chi2_contingency(pd.crosstab(clus_abide_df.loc[:, ['clus_id', 'ADOS_MODULE']].dropna()['clus_id'],
                             clus_abide_df.loc[:, ['clus_id', 'ADOS_MODULE']].dropna()['ADOS_MODULE']))
# Out:
# (14.770498760653702,
#  0.005201671596169259,
#  4,
#  array([[  1.92903226,  73.7483871 ,  39.32258065],
#         [  4.22709677, 161.60516129,  86.16774194],
#         [  6.84387097, 261.64645161, 139.50967742]]))

# %%
clus_abide_df.loc[:, ['clus_id', 'VINELAND_WRITTEN_V_SCALED']].dropna().groupby('clus_id').count()
# Out:
#          VINELAND_WRITTEN_V_SCALED
# clus_id
# clus_1                          36
# clus_2                          37
# clus_3                          66

# %%
clus_abide_df.loc[:, ['clus_id', 'VINELAND_WRITTEN_V_SCALED']].dropna().groupby('clus_id').mean()
# Out:
#          VINELAND_WRITTEN_V_SCALED
# clus_id
# clus_1                   15.166667
# clus_2                   14.729730
# clus_3                   13.196970

# %%
f_oneway(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,'VINELAND_WRITTEN_V_SCALED'].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])
# Out:
# F_onewayResult(statistic=6.176177450190405, pvalue=0.0027078433626887477)

# %%
clus_abide_df.loc[:, ['clus_id', 'VINELAND_COMMUNITY_V_SCALED']].dropna().groupby('clus_id').count()
# Out:
#          VINELAND_COMMUNITY_V_SCALED
# clus_id
# clus_1                            36
# clus_2                            37
# clus_3                            66

# %%
clus_abide_df.loc[:, ['clus_id', 'VINELAND_COMMUNITY_V_SCALED']].dropna().groupby('clus_id').mean()
# Out:
#          VINELAND_COMMUNITY_V_SCALED
# clus_id
# clus_1                     13.055556
# clus_2                     14.945946
# clus_3                     12.818182

# %%
f_oneway(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,'VINELAND_COMMUNITY_V_SCALED'].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])
# Out:
# F_onewayResult(statistic=6.895333784805102, pvalue=0.0014050194661370094)

# %%
f_oneway(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,'VINELAND_COMMUNITY_V_SCALED'].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])

# %%
for column in p_columns:

    f, p = kruskal(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,column].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])

    plt.figure(figsize=(10,6))
    sns.set_style(style='whitegrid')
    sns.despine(offset=10, trim=True)
    plt.figure(figsize=(10,6))
    sns.barplot(x="clus_id", y = column, 
               data=clus_abide_df, saturation=.9, 
                estimator=np.median,
                capsize=.05,
                linewidth=0.,#2.5,
                alpha=0.,
                errwidth = 3,
                errcolor=".05", 
                edgecolor=".05")

    sns.stripplot(x="clus_id", y = column, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

    #ax = sns.violinplot(x="clus_id", y = column, 
     #          data=clus_abide_df, saturation=1,
      #         inner = None,
       #        alpha=0.1,
        #       linewidth=0)
    plt.setp(ax.collections[4:], alpha=.1)

    plt.xlabel(" ")
    plt.ylabel(" ")
    plt.yticks(size=15)
    
    xticks = list(range(len(clus_abide_df.clus_id.unique())))
    xticklabels = clus_abide_df.clus_id.unique()
                  
    plt.xticks(xticks, xticklabels, 
               fontsize = 20, fontweight = 'bold')
    plt.title(column + "\n (p = %.3f)" % p, size=30, weight ='bold')
    plt.tight_layout()
    #plt.savefig(opj(plot_dir, var +".png"))
    pass

# %%
[demo_w_clusters.loc[demo_w_clusters.clus_id==(ii+1), 'AGE_AT_SCAN'].dropna().mean() for ii in range(3)]
# Out:
# [14.936236429933889, 16.29394330733452, 16.211499374747834]

# %%
var = 'AGE_AT_SCAN'
f, p = f_oneway(*[clus_abide_df.loc[clus_abide_df.clus_id==clus_id,'AGE_AT_SCAN'].dropna() for 
                     clus_id in clus_abide_df.clus_id.unique()])

plt.figure(figsize=(10,6))

sns.violinplot(x="clus_id", y = "AGE_AT_SCAN", data=clus_abide_df,saturation=.5,
             linewidth=2.5, errwidth=2.5, errcolor=".2", cut=2,
             capsize=.1)
plt.xlabel(" ")

plt.ylabel(" ")
plt.yticks(size=12)
plt.title("AGE_AT_SCAN \n (ANOVA p = %.3f)" % p, size=15)
#plt.savefig(opj(plot_dir, "AGE_AT_SCAN.png"))
pass

# %%
observed_table = pd.crosstab(clus_abide_df['clus_id'],
                       clus_abide_df['SEX']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)

sns.countplot(x="clus_id", hue = "SEX", data=clus_abide_df)
plt.title("SEX (chi2 p = %.3f)" % p)
pass

# %%
ax.collections

# %%
var = 'VINELAND_WRITTEN_V_SCALED'
title = 'VINELAND WRITTEN V SCALED'

f, p = kruskal(*[clus_abide_df.loc[clus_abide_df['clus_id'] == clus_id ,var].dropna() \
                for clus_id in clus_abide_df['clus_id'].unique()])
               
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
            data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
                    data=clus_abide_df, saturation=1,
                    inner = None,
                    alpha=0.1,
                    linewidth=0)

plt.setp(ax.collections[3:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2], ['cluster 1', 'cluster 2', 'cluster 3'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
#plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var_1 = 'VINELAND_WRITTEN_V_SCALED'
title_1 = 'VINELAND WRITTEN V SCALED'

var_2 = 'VINELAND_COMMUNITY_V_SCALED'
title_2 = 'VINELAND_COMMUNITY_V_SCALED'


f_1, p_1 = kruskal(*[clus_abide_df.loc[clus_abide_df['clus_id'] == clus_id ,var_1].dropna() \
                for clus_id in clus_abide_df['clus_id'].unique()])

f_2, p_2 = kruskal(*[clus_abide_df.loc[clus_abide_df['clus_id'] == clus_id ,var_2].dropna() \
                for clus_id in clus_abide_df['clus_id'].unique()])

with sns.axes_style("ticks"):

    fig, axs  = plt.subplots(figsize=(14,5), ncols=2)
    sns.boxplot(x="clus_id", y = var_1, 
                data=clus_abide_df, 
                 linewidth=2,
                width=0.5, 
               ax=axs[0])
    
    sns.boxplot(x="clus_id", y = var_2, 
                data=clus_abide_df, 
                 linewidth=2,
                width=0.5, 
               ax=axs[1])


    sns.stripplot(x="clus_id", 
                  y = var_1, 
                  data=clus_abide_df,
                  size=5, 
                  alpha=1,
                  edgecolor='black',
                   color=".25",
                 ax=axs[0])
    
    sns.stripplot(x="clus_id", 
              y = var_2, 
              data=clus_abide_df,
              size=5, 
              alpha=1,
              edgecolor='black',
               color=".25",
             ax=axs[1])


    #plt.setp(ax.collections[3:], alpha=.2)
    sns.despine(offset=10, trim=True)
    axs[0].set_xlabel(" ")
    axs[0].set_ylabel(" ")
    #axs[0].set_yticklabels(size=15)
    axs[0].set_xticklabels(['cluster 1', 'cluster 2', 'cluster 3'], 
                           size = 15, fontweight = 'bold')
    axs[0].set_title(title_1 + "\n (p = %.3f)" % p_1, 
                     size=20, weight ='bold')
    axs[0].tick_params(axis='both', which='major', labelsize=15)
    
    #axs[1].set_yticklabels(size=15)
    axs[1].set_xlabel(" ")
    axs[1].set_ylabel(" ")
    axs[1].set_xticklabels(['cluster 1', 'cluster 2', 'cluster 3'], 
                           size = 15, fontweight = 'bold')
    axs[1].set_title(title_2 + "\n (p = %.3f)" % p_2, 
                     size=20, weight ='bold')
    
    axs[1].tick_params(axis='both', which='major', labelsize=15)
    plt.tight_layout()
    
    
    #plt.savefig(opj(plot_dir, var +".png"))
    pass

# %%
sp.posthoc_dunn?

# %%
import scikit_posthocs as sp

foo = [clus_abide_df.loc[ids, var_1].values \
       for ids in clus_abide_df.groupby('clus_id').groups.values()]

print(kruskal(*foo, nan_policy='omit'))
sp.posthoc_dunn(clus_abide_df.loc[:, [var_1, 'clus_id']].dropna(), 
                       val_col=var_1, 
                       group_col='clus_id', p_adjust = 'holm')
# Out:
# KruskalResult(statistic=12.252199706843893, pvalue=0.0021850865211855914)
#           clus_1    clus_2    clus_3
# clus_1 -1.000000  0.472173  0.003845
# clus_2  0.472173 -1.000000  0.030278
# clus_3  0.003845  0.030278 -1.000000

# %%
sp.posthoc_dunn?

# %%
foo = [clus_abide_df.loc[ids, var_2].values \
       for ids in clus_abide_df.groupby('clus_id').groups.values()]

print(kruskal(*foo, nan_policy='omit'))
sp.posthoc_dunn(clus_abide_df.loc[:, [var_2, 'clus_id']].dropna(), 
                       val_col=var_2, 
                       group_col='clus_id', p_adjust = 'holm')
# Out:
# KruskalResult(statistic=12.870111318935129, pvalue=0.001604319404349937)
#           clus_1    clus_2    clus_3
# clus_1 -1.000000  0.015424  0.657408
# clus_2  0.015424 -1.000000  0.001479
# clus_3  0.657408  0.001479 -1.000000

# %%
var = 'ADI_R_SOCIAL_TOTAL_A'º
title = 'ADI-R SOCIAL TOTAL'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=1,
               inner = None,
               alpha=0.1,
               linewidth=0)

plt.setp(ax.collections[4:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_COMM'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())

plt.figure(figsize=(10,6))
sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9,
               inner = 'quartile',
               linewidth=3, color='white')

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,  jitter=True, linewidth=.5, alpha=0.5)


plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(var + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_COMM'
title = 'ADOS COMMUNICATION'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=1,
               inner = None,
               alpha=0.1,
               linewidth=0)

plt.setp(ax.collections[4:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_GOTHAM_SOCAFFECT'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())


plt.figure(figsize=(10,6))
sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9,
               inner = 'quartile',
               linewidth=3, color='white')

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,  jitter=True, linewidth=.5, alpha=0.5)


plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')

if p<0.001:
    plt.title(var + "\n (p <0.001)" % p, size=30, weight ='bold')
else:
    plt.title(var + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_GOTHAM_SOCAFFECT'
title = 'ADOS GOTHAM SOCIAL AFFECT'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=1,
               inner = None,
               alpha=0.1,
               linewidth=0)

plt.setp(ax.collections[4:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_GOTHAM_SEVERITY'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())


plt.figure(figsize=(10,6))
sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9,
               inner = 'quartile',
               linewidth=3, color='white')

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,  jitter=True, linewidth=.5, alpha=0.5)


plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')

if p<0.001:
    plt.title(var + "\n (p <0.001)" % p, size=30, weight ='bold')
else:
    plt.title(var + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_GOTHAM_SEVERITY'
title = 'ADOS GOTHAM SEVERITY'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=1,
               inner = None,
               alpha=0.1,
               linewidth=0)

plt.setp(ax.collections[4:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_GOTHAM_TOTAL'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())


plt.figure(figsize=(10,6))
sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9,
               inner = 'quartile',
               linewidth=3, color='white')

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,  jitter=True, linewidth=.5, alpha=0.5)


plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')

if p<0.001:
    plt.title(var + "\n (p <0.001)" % p, size=30, weight ='bold')
else:
    plt.title(var + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()   
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'ADOS_GOTHAM_TOTAL'
title = 'ADOS GOTHAM TOTAL'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=1,
               inner = None,
               alpha=0.1,
               linewidth=0)

plt.setp(ax.collections[4:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','VINELAND_COMMUNITY_V_SCALED'].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','VINELAND_COMMUNITY_V_SCALED'].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','VINELAND_COMMUNITY_V_SCALED'].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4','VINELAND_COMMUNITY_V_SCALED'].dropna())

sns.stripplot(x="clus_id", y = "VINELAND_COMMUNITY_V_SCALED", 
              data=clus_abide_df)

sns.barplot(x="clus_id", y = "VINELAND_COMMUNITY_V_SCALED", 
            data=clus_abide_df, saturation=.5,
            linewidth=2.5, errwidth=2.5, errcolor=".2",
            capsize=.1)

plt.title("VINELAND_COMMUNITY_V_SCALED (KRUSKAL p = %.3f)" % p)
pass

# %%
var = 'VINELAND_WRITTEN_V_SCALED'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna(),
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())


plt.figure(figsize=(10,6))
sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9,
               inner = 'quartile',
               linewidth=3, color='white')

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,  jitter=True, linewidth=.5, alpha=0.5)


plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')

if p<0.001:
    plt.title(var + "\n (p <0.001)" % p, size=30, weight ='bold')
else:
    plt.title(var + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()    
plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
var = 'VINELAND_WRITTEN_V_SCALED'
title = 'VINELAND WRITTEN LANGUAGE V SCALED'

f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2',var].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3',var].dropna())#,
               #clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4',var].dropna())
sns.set_style(style='whitegrid')
sns.despine(offset=10, trim=True)
plt.figure(figsize=(10,6))
sns.barplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=.9, 
            estimator=np.median,
            capsize=.05,
            linewidth=0.,#2.5,
            alpha=0.,
            errwidth = 3,
            errcolor=".05", edgecolor=".05")

sns.stripplot(x="clus_id", y = var, 
              data=clus_abide_df,
              jitter=0.2, alpha=0.5)

ax = sns.violinplot(x="clus_id", y = var, 
               data=clus_abide_df, saturation=1,
               inner = None,
               alpha=0.1,
               linewidth=0)

plt.setp(ax.collections[4:], alpha=.2)

plt.xlabel(" ")
plt.ylabel(" ")
plt.yticks(size=15)
plt.xticks([0, 1, 2, 3], ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 20, fontweight = 'bold')
plt.title(title + "\n (p = %.3f)" % p, size=30, weight ='bold')
plt.tight_layout()
#plt.savefig(opj(plot_dir, var +".png"))
pass

# %%
f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','VINELAND_EXPRESSIVE_V_SCALED'].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','VINELAND_EXPRESSIVE_V_SCALED'].dropna(), 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','VINELAND_EXPRESSIVE_V_SCALED'].dropna())

sns.stripplot(x="clus_id", y = "VINELAND_EXPRESSIVE_V_SCALED", 
              data=clus_abide_df)

sns.barplot(x="clus_id", y = "VINELAND_EXPRESSIVE_V_SCALED", 
            data=clus_abide_df, saturation=.5,
            linewidth=2.5, errwidth=2.5, errcolor=".2",
            capsize=.1)

plt.title("VINELAND_EXPRESSIVE_V_SCALED (KRUSKAL p = %.3f)" % p)
pass

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15,5))

h, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','VIQ'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','VIQ'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','VIQ'], nan_policy='omit')

sns.violinplot(x="clus_id", y = "VIQ", data=clus_abide_df, ax= axs[0])
axs[0].set_title("VIQ (Kruska-Wallis p= %.3f)" % p)
#print("Kruskal-Wallis p-value for VIQ = ", p)
      
h, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','FIQ'], 
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','FIQ'],  
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','FIQ'], nan_policy='omit')
      
#print("Kruskal-Wallis p-value for FIQ = ", p)
sns.violinplot(x="clus_id", y = "FIQ", data=clus_abide_df, ax= axs[1])
axs[1].set_title("FIQ (Kruska-Wallis p= %.3f)" % p)

h, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','PIQ'], 
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','PIQ'], 
               clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','PIQ'], nan_policy='omit')

#print("Kruskal-Wallis p-value for PIQ = ", p)
sns.violinplot(x="clus_id", y = "PIQ", data=clus_abide_df, ax= axs[2])
axs[2].set_title("PIQ (Kruska-Wallis p = %.3f)" % p)

plt.suptitle("IQ TESTS")
pass

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))

h, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','ADI_R_SOCIAL_TOTAL_A'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','ADI_R_SOCIAL_TOTAL_A'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','ADI_R_SOCIAL_TOTAL_A'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4','ADI_R_SOCIAL_TOTAL_A'], nan_policy='omit')

sns.barplot(x="clus_id", y = "ADI_R_SOCIAL_TOTAL_A", data=clus_abide_df, ax= axs[0])

axs[0].set_title("ADI_R_SOCIAL_TOTAL_A (Kruska-Wallis p = %.3f)" % p)

#print("Kruskal-Wallis p-value for ADI_R_SOCIAL_TOTAL_A = ", p)

h, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','ADI_R_VERBAL_TOTAL_BV'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','ADI_R_VERBAL_TOTAL_BV'], 
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','ADI_R_VERBAL_TOTAL_BV'],
 clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_4','ADI_R_VERBAL_TOTAL_BV'], nan_policy='omit')

#print("Kruskal-Wallis p-value for ADI_R_VERBAL_TOTAL_BV = ", p)
sns.barplot(x="clus_id", y = "ADI_R_VERBAL_TOTAL_BV", data=clus_abide_df, ax= axs[1])
axs[1].set_title("ADI_R_VERBAL_TOTAL_BV (Kruska-Wallis p = %.3f)" % p)


plt.suptitle("ADI TESTS")
pass

# %% [markdown]
# The modules provide social-communicative sequences that combine a series of unstructured and structured situations. Each situation provides a different combination of presses for particular social behaviors.
#
#     -Module 1 is intended for individuals who do not consistently use phrase speech (defined as non-echoed. three-word utterances that sometimes involve a verb and that are spontaneous, meaningful word combinations). Materials for Module 1 have been selected for young children, but materials from other modules may be substituted if desired.
#
#     - Module 2 is intended for individuals with some phrase speech who are not verbally fluent.
#
#     - Module 3 is intended for verbally fluent children for whom playing with toys is age-appropriate (usually up to 12 - 16 years of age). Verbal fluency is broadly defined as having the expressive language of a typical four-year-old child: producing a range of sentence types and grammatical forms, using language to provide information about events out of the context of the ADOS, and producing some logical connections within sentences (e.g., "but" or "though").
#
#     - Module 4 includes the many of the tasks in Module 3 (some of which are optional), as well as additional interview items about daily living. It is intended for verbally-fluent adolescents and adults. The difference between Modules 3 and 4 lies primarily in whether information about social-communication is more appropriately acquired during play or a conversational interview.

# %%
# f, p = kruskal(clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_1','ADOS_MODULE'].dropna(), 
#  clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_2','ADOS_MODULE'].dropna(), 
#  clus_abide_df.loc[clus_abide_df['clus_id'] == 'clus_3','ADOS_MODULE'].dropna())

chi, p,_ ,_ = chi2_contingency(pd.crosstab(clus_abide_df.ADOS_MODULE,clus_abide_df.clus_id))

sns.countplot(x="clus_id", hue = "ADOS_MODULE", 
              data=clus_abide_df)


# sns.barplot(x="clus_id", y = "ADOS_MODULE", 
#             data=clus_abide_df, saturation=.5,
#             linewidth=2.5, errwidth=2.5, errcolor=".2",
#             capsize=.1)

plt.title("ADOS_MODULE (chi 2 p = %.3f)" % p)
pass

# %%
cond = (clus_abide_df['DSM_IV_TR']>0) & (clus_abide_df['DSM_IV_TR']<4)

observed_table = pd.crosstab(clus_abide_df.loc[cond, 'clus_id'],
                             clus_abide_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)


this_df = clus_abide_df.loc[cond,:].copy()

this_df.DSM_IV_TR = this_df.DSM_IV_TR.astype(str).replace(to_replace = ["1.0", "2.0", "3.0"], 
                                                          value=['Autism', 'Aspergers', 'PDD-NOS'])


# Create colors
a, b, c = [plt.cm.Purples, plt.cm.Greys, plt.cm.PuRd]

fig, axs = plt.subplots(ncols=2, figsize=(10,5))


sns.countplot(x='clus_id', hue = 'DSM_IV_TR', 
              data = this_df, 
              ax=axs[0], palette =  [a(0.75), b(0.6), c(0.7)])

group_names= ['Aspergers', 'Autism', 'PDD-NOS'] 
group_size = this_df.groupby(["DSM_IV_TR"]).sum()['DX_GROUP'].values
subgroup_names   = ['clus 1', 'clus 2' ,'clus 3', 'clus 4', 'clus 1', 'clus 2' ,'clus 3',  'clus 4',
                    'clus 1', 'clus 2' ,'clus 3',  'clus 4']
subgroup_size = this_df.groupby(["DSM_IV_TR", "clus_id"]).sum()['DX_GROUP'].values    

# First Ring (outside)
#fig, ax = plt.subplots()
axs[1].axis('equal')
mypie, _ = axs[1].pie(group_size[::-1], radius=1.3, 
                      labels=group_names[::-1], colors=[b(0.6), a(0.75), c(0.7)][::-1], textprops={'size':15,
                                                                                                  'weight':'bold'})

plt.setp(mypie, width=0.3, edgecolor='white')
 
# Second Ring (Inside)
mypie2, _ = axs[1].pie(subgroup_size[::-1], radius=1.3-0.3, labels=subgroup_names[::-1], 
                   labeldistance=0.7, colors=[b(0.5), b(0.4), b(0.3), b(0.2), 
                                              a(0.6), a(0.5), a(0.4), a(0.2), 
                                              c(0.5), c(0.4), c(0.3), c(0.2)][::-1],
                       textprops={'size':8, 'weight':'bold'})

plt.setp(mypie2, width=0.4, edgecolor='white')
plt.margins(0,0)
if p<0.001:
    axs[0].set_title("DSM_IV_TR \n (p < %.3f)" % 0.001, size=20, weight='bold')
else:
    axs[0].set_title("DSM_IV_TR \n (p = %.3f)" % p, size=20, weight='bold')
    
axs[0].set_xlabel("")
axs[0].set_ylabel("# Cases", size=20, weight='bold')
axs[0].tick_params(axis = 'y', labelsize=15)
axs[0].set_xticklabels(['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], 
           fontsize = 10, fontweight = 'bold')

axs[1].set_xticklabels(['Autism', 'Aspergers', 'PDD-NOS'], 
           fontsize = 30, fontweight = 'bold')
pass
plt.tight_layout()
#plt.savefig(opj(plot_dir, 'dsm_types.png'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d0052f7d2a47> in <module>
#      43                                               a(0.6), a(0.5), a(0.4), a(0.2),
#      44                                               c(0.5), c(0.4), c(0.3), c(0.2)][::-1],
# ---> 45                        textprops={'size':8, 'weight':'bold'})
#      46
#      47 plt.setp(mypie2, width=0.4, edgecolor='white')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)
# Out:
# 2.631615450787611e-06

# %%
cond = (this_df.clus_id == 'clus_1') | (this_df.clus_id == 'clus_2')

observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)

cond = (this_df.clus_id == 'clus_1') | (this_df.clus_id == 'clus_3')

observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)

cond = (this_df.clus_id == 'clus_1') | (this_df.clus_id == 'clus_4')

observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)

cond = (this_df.clus_id == 'clus_2') | (this_df.clus_id == 'clus_3')

observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)

cond = (this_df.clus_id == 'clus_2') | (this_df.clus_id == 'clus_4')

observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)

cond = (this_df.clus_id == 'clus_3') | (this_df.clus_id == 'clus_4')

observed_table = pd.crosstab(this_df.loc[cond, 'clus_id'],
                             this_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)
# Out:
# 0.00015802202623641545
# 7.244160164830758e-07
# 1.0
# 0.4740188870052263
# 1.0
# 1.0

# %%
plt.figure(figsize=(10, 10))
fig = sns.countplot(x='clus_id', hue = 'SITE_ID', data = clus_abide_df, 
                    palette = sns.color_palette("Set2", n_colors=len(clus_abide_df.SITE_ID.unique()), desat=.5))
plt.legend(ncol=3)

# %%
clus_abide_df.

# %%
observed_table = pd.crosstab(clus_abide_df.loc[:, 'clus_id'],
                             clus_abide_df.loc[:, 'SITE_ID']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)
print(p)
# Out:
# 1.0034681862591916e-08

# %%
np.array(observed_table)
# Out:
# array([[ 4,  3,  1,  1,  0,  9,  0,  2,  2,  3, 33,  1,  9,  1,  1,  1,
#          4,  3,  0,  2,  2,  9,  5, 13],
#        [12,  7,  5, 11,  6, 11,  3, 36,  9,  8, 42, 12,  3,  3, 11,  5,
#         16,  5, 20,  6, 19, 19, 32,  3],
#        [13,  8,  7, 10,  5, 27, 14, 38, 17, 11, 74, 24,  6,  3, 18,  9,
#         26,  6, 24,  9, 30, 29, 38, 10]])

# %%
#This result is not reliable as some cells have very few examples for chi2 test to be valid
print("The percent of cells "
      "with at least 5 observations is "
      "%.2f" % (100-100*np.sum(np.array(expected_table)<5)/np.array(expected_table).size))
# Out:
# The percent of cells with at least 5 observations is 65.28

# %% [markdown]
# # POST-HOC comparisons for the significant tests

# %%
import scikit_posthocs as sp

# %%
for ii, var in enumerate(['ADI_R_SOCIAL_TOTAL_A', 'ADOS_COMM', 
                          'ADOS_GOTHAM_TOTAL', 'VINELAND_WRITTEN_V_SCALED',
                          'ADOS_GOTHAM_SEVERITY', 'ADOS_GOTHAM_SOCAFFECT']):
    
    post_res = sp.posthoc_conover(clus_abide_df.loc[:, [var, 'clus_id']].dropna(),
                                      val_col=var, group_col='clus_id', p_adjust = 'fdr_bh')
    
    print(var)
    print(post_res)
    print(" ")
# Out:
# ADI_R_SOCIAL_TOTAL_A
#           clus_1    clus_2    clus_3    clus_4
# clus_1 -1.000000  0.615943  0.636217  0.373687
# clus_2  0.615943 -1.000000  0.636217  0.035414
# clus_3  0.636217  0.636217 -1.000000  0.035414
# clus_4  0.373687  0.035414  0.035414 -1.000000
#
# ADOS_COMM
#           clus_1    clus_2    clus_3    clus_4
# clus_1 -1.000000  0.292315  0.739268  0.465506
# clus_2  0.292315 -1.000000  0.055055  0.663589
# clus_3  0.739268  0.055055 -1.000000  0.119646
# clus_4  0.465506  0.663589  0.119646 -1.000000
#
# ADOS_GOTHAM_TOTAL
#           clus_1    clus_2    clus_3    clus_4
# clus_1 -1.000000  0.003903  0.348522  0.029443
# clus_2  0.003903 -1.000000  0.003903  0.348522
# clus_3  0.348522  0.003903 -1.000000  0.040466
# clus_4  0.029443  0.348522  0.040466 -1.000000
#
# VINELAND_WRITTEN_V_SCALED
#           clus_1    clus_2    clus_3    clus_4
# clus_1 -1.000000  0.038171  0.003591  0.196417
# clus_2  0.038171 -1.000000  0.933253  0.277304
# ...

# %%
fig, axs = plt.subplots(ncols=3, nrows=2, sharex=True, sharey=True, figsize=(10, 10))
axs = axs.flatten()
for ii, var in enumerate(['ADI_R_SOCIAL_TOTAL_A', 'ADOS_COMM', 
                          'ADOS_GOTHAM_TOTAL', 'VINELAND_WRITTEN_V_SCALED',
                          'ADOS_GOTHAM_SEVERITY', 'ADOS_GOTHAM_SOCAFFECT']):
    
    post_res = sp.posthoc_conover(clus_abide_df.loc[:, [var, 'clus_id']].dropna(),
                                      val_col=var, group_col='clus_id', p_adjust = 'fdr_bh')
    
    
    axs[ii].imshow(post_res<0.05, cmap=plt.cm.Greys_r)
    axs[ii].set_xticks([0,1,2,3])
    axs[ii].set_xticklabels(['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'], rotation = 90)
    axs[ii].set_yticks([0,1,2,3])
    axs[ii].set_yticklabels(['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'])
    axs[ii].set_title(var)
plt.tight_layout()

# %%
cond = (clus_abide_df['DSM_IV_TR']>0) & (clus_abide_df['DSM_IV_TR']<4)

observed_table = pd.crosstab(clus_abide_df.loc[cond, 'clus_id'],
                             clus_abide_df.loc[cond, 'DSM_IV_TR']).values.tolist()

chi2, p, _, expected_table = chi2_contingency(observed_table)

# %%
from itertools import combinations

all_combinations = list(combinations(clus_abide_df.clus_id.unique(), 2))
p_vals = []

df = clus_abide_df.loc[cond,:].copy()
for comb in all_combinations:
    new_df = df[(df.clus_id == comb[0]) | (df.clus_id == comb[1])]
    observed_table = pd.crosstab(new_df.loc[cond, 'clus_id'],
                                 new_df.loc[cond, 'DSM_IV_TR']).values.tolist()
    # running chi2 test
    chi2, p, dof, ex = chi2_contingency(observed_table, correction=True)
    p_vals.append(p)

# %%
from statsmodels.sandbox.stats.multicomp import multipletests

reject_list, corrected_p_vals = multipletests(p_vals, method='fdr_bh')[:2]

for comb, pv in zip(all_combinations, corrected_p_vals):
    print("%s vs %s = %.3f" % (comb[0], comb[1], pv))
# Out:
# clus_1 vs clus_2 = 0.014
# clus_1 vs clus_3 = 0.000
# clus_1 vs clus_4 = 0.000
# clus_2 vs clus_3 = 0.515
# clus_2 vs clus_4 = 0.515
# clus_3 vs clus_4 = 0.825

# %%
demo_w_clusters = pd.read_excel('../data/pheno_w_clusters.xlsx')
Y_combat = np.load('../data/data_after_combat.npz')['Y_combat']

# %%
y = demo_w_clusters.loc[:, 'clus_id'].astype(int).values

# %%
sum(y==3)
# Out:
# 464

# %%
print(demo_w_clusters.loc[demo_w_clusters.clus_id==0, 'VIQ'].mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==1, 'VIQ'].mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==2, 'VIQ'].mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==3, 'VIQ'].mean())
# Out:
# 114.08575031525851
# 102.67676767676768
# 106.25777777777778
# 106.86666666666666

# %%
kruskal(*[demo_w_clusters.loc[demo_w_clusters.clus_id==1, 'VIQ'].dropna(),
          demo_w_clusters.loc[demo_w_clusters.clus_id==2, 'VIQ'].dropna(),
          demo_w_clusters.loc[demo_w_clusters.clus_id==3, 'VIQ'].dropna()])
# Out:
# KruskalResult(statistic=5.55018831934548, pvalue=0.062343606159740744)

# %%
n_0 = sum(y==0)
n_1 = sum(y==1)
n_2 = sum(y==2)
n_3 = sum(y==3)

d_1 = np.corrcoef(Y_combat[(y==0) | (y==1), :])[:n_0,n_0:]
d_2 = np.corrcoef(Y_combat[(y==0) | (y==2), :])[:n_0,n_0:]
d_3 = np.corrcoef(Y_combat[(y==0) | (y==3), :])[:n_0,n_0:]

# %%
plt.boxplot(d_1.flatten())
plt.boxplot(d_2.flatten())
plt.boxplot(d_3.flatten())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fabd8306210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fabd8864e90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fabd83061d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fabd873f8d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fabd873fdd0>],
#  'means': []}

# %%
kruskal(*[d_1.flatten(), d_2.flatten(), d_3.flatten()])
# Out:
# KruskalResult(statistic=19911.954365246464, pvalue=0.0)

# %%
from scipy.stats import ttest_ind

# %%
demo_w_clusters.columns
# Out:
# Index(['SUB_ID', 'SITE_ID', 'DX_GROUP', 'DSM_IV_TR', 'AGE_AT_SCAN', 'SEX',
#        'HANDEDNESS_CATEGORY', 'HANDEDNESS_SCORES', 'FIQ', 'VIQ', 'PIQ',
#        'FIQ_TEST_TYPE', 'VIQ_TEST_TYPE', 'PIQ_TEST_TYPE',
#        'ADI_R_SOCIAL_TOTAL_A', 'ADI_R_VERBAL_TOTAL_BV', 'ADI_RRB_TOTAL_C',
#        'ADI_R_ONSET_TOTAL_D', 'ADI_R_RSRCH_RELIABLE', 'ADOS_MODULE',
#        'ADOS_TOTAL', 'ADOS_COMM', 'ADOS_SOCIAL', 'ADOS_STEREO_BEHAV',
#        'ADOS_RSRCH_RELIABLE', 'ADOS_GOTHAM_SOCAFFECT', 'ADOS_GOTHAM_RRB',
#        'ADOS_GOTHAM_TOTAL', 'ADOS_GOTHAM_SEVERITY', 'SRS_VERSION',
#        'SRS_RAW_TOTAL', 'SRS_AWARENESS', 'SRS_COGNITION', 'SRS_COMMUNICATION',
#        'SRS_MOTIVATION', 'SRS_MANNERISMS', 'SCQ_TOTAL', 'AQ_TOTAL',
#        'COMORBIDITY', 'CURRENT_MED_STATUS', 'MEDICATION_NAME',
#        'OFF_STIMULANTS_AT_SCAN', 'VINELAND_RECEPTIVE_V_SCALED',
#        'VINELAND_EXPRESSIVE_V_SCALED', 'VINELAND_WRITTEN_V_SCALED',
# ...

# %%
print(demo_w_clusters.loc[demo_w_clusters.clus_id==1, 'ADOS_TOTAL'].dropna().mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==2, 'ADOS_TOTAL'].dropna().mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==3, 'ADOS_TOTAL'].dropna().mean())
# Out:
# 12.0
# 11.351648351648352
# 11.517241379310345

# %%
print(demo_w_clusters.loc[demo_w_clusters.clus_id==1, 'FIQ'].dropna().mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==2, 'FIQ'].dropna().mean())
print(demo_w_clusters.loc[demo_w_clusters.clus_id==3, 'FIQ'].dropna().mean())
# Out:
# 104.10084033613445
# 106.98455598455598
# 106.54107981220658

# %%
kruskal(*[demo_w_clusters.loc[demo_w_clusters.clus_id==1, 'PIQ'].dropna(),
          demo_w_clusters.loc[demo_w_clusters.clus_id==2, 'PIQ'].dropna(),
          demo_w_clusters.loc[demo_w_clusters.clus_id==3, 'PIQ'].dropna()])
# Out:
# KruskalResult(statistic=1.8936488907870248, pvalue=0.3879710927354524)
